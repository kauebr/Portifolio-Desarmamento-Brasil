# %% [markdown]
# <center>
#     <img src="https://i.ibb.co/wQg0qzq/Banner.png" width="900" alt="KCode Banner"  />
# </center>
# <a href="https://www.linkedin.com/in/kauebr/"><img src="https://cdn-icons-png.flaticon.com/512/174/174857.png" width="30" ></a> <a href="mailto: kauemandarino@gmail.com"><img src="https://cdn-icons-png.flaticon.com/512/5968/5968534.png" width="30" ></a><a href="
# https://api.whatsapp.com/send?phone=5541991835800&text=Oi"> <img src="https://imagepng.org/wp-content/uploads/2017/08/whatsapp-icone-1.png" width="30" ></a><a href="https://github.com/kauebr/"><img src="https://github.githubassets.com/images/modules/logos_page/Octocat.png" width="30" ></a>
#
# <HR>

# %% [markdown]
# > Curitiba 2022
#
# > Em Criação...

# %% [markdown]
# # Desarmamento Brasil

# %% [markdown]
# # <h2 id="1">1. Contexto</h2>

# %% [markdown]
# Após séculos de livre circulação de armas desde o Brasil colônia, `na década de 90`(Governo Fernando Henrique Cardoso) `o Brasil já tinha sua própria indústria bélica`, em 1991 o [projeto de lei 2246](https://www.camara.leg.br/proposicoesWeb/fichadetramitacao?idProposicao=201408) de `autoriade Eduardo Jorge(PT-SP)` visava limitar a circulução de armas no território nacional, através da proibição do porte de armas em território nacional, exceto algumas exceções como as forças armadas. No dia 23 de
# outubro de `2005(Governo Lula)`, o povo brasileiro foi chamado às urnas, através de um [referendo popular](https://www.youtube.com/watch?v=6sGADvxsEIY), a população foi convidada à dar sua opinião sobre a proibição do comércio de armas de fogo e munições no país, aonde a `maioria(63%) votou a favor do comércio de armas`, apesar da decisão popular favorável ao comercio, o governo de `esquerda` realizou alteração no art. 35 do estatuto do desarmamento (Lei nº 10.826/2003) e `tornou proibida a comercialização de armas de fogo` e munição em todo o território nacional, salvo para as entidades previstas no art. 6º do estatuto. `Comprar e portar armas no Brasil por meios legais ficou praticamente impossível`. Em 5 anos, de 2008 até 2012, a polícia federal autorizou a compra de apenas 3.336 armas por civis em todo o país, a população estimada do Brasil era na época de 194 mi. de habitantes. Em 2014 a campanha de desarmamento já havia recolhido quase 650 mil armas de circulação.
# Em `2018` O militar reformado `Jair Bolsonaro foi eleito` o 38.º presidente do Brasil com 55,13% dos votos válidos, no segundo turno das eleições presidenciais, um das principais `prioridades de sua campanha`, foi a `liberação do comércio de armas`, sendo inclusive `seu símbolo de campanha uma "arminha"` com a mão. Eleito a Bolsonaro publicou mais de 30 decretos e atos normativos desde janeiro de `2019` para facilitar o `acesso às armas`. Embora muitos ainda estejam judicializados, pois os processos enfrentaram [resistência no senado](https://www12.senado.leg.br/noticias/materias/2022/2021/07/23/decretos-pro-armas-de-bolsonaro-enfrentam-resistencia-no-senado), a intenção de aumentar o `acesso ao armamento` ao cidadão comum foi atingida.
#
# Neste contexto, vale ressaltar, que durante o advento das redes sociais, houve uma `polarização política, esquerda x direita`, no Brasil, aonde a população elegeu um lado e vimos surgir muitos discursos de ódio, tanto da direita pela esquerda quanto da esquerda pela direita. Esta polarização tornou muito rara uma `visão analítica de cenários`, sendo comum ante a realidade dos fatos ser posto um discurso polarizado de ódio, em que apenas se discorda do outro lado, sem uma análise real dos fatos e consequências em si. Este estudo é uma análise imparcial, `vamos nos basear em dados`, para que cheguemos a uma `resposta dos impactos das políticas armamentistas durante os anos`, e que sejam gerados insights e informações valiosas para auxiliar a tomada de decisões futuras, prevendo as tendências e consequências de cada política, analiticamente, `sem que se defenda um partido ou um viés político`.
#
# Nesse contexto este estudo deseja analisar com base em dados qual foi o impacto da rigidez e do afrouxamento nas políticas
# de desarmamento do Brasil em relação à violência por armas de fogo.
#
# É importante destacar que a PF faz o registro das armas usadas por civis, como servidores públicos com porte funcional,
# empresas de segurança privada e cidadãos comuns, entre outras categorias. E cabe ao Exército fazer o controle de armas
# de militares e de caçadores, atiradores e colecionadores (CACs).

# %% [markdown]
# # <h1>Índice</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href=#1>Contexto</a></li>
#         <li><a href=#2>Objetivo Geral</a></li>
#         <li><a href=#3>Objetivos Específicos</a></li>
#         <li><a href=#4>Mineração de dados - Criando Conjunto de Dados</a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# # <h2 id="2">2. Objetivo Geral</h2>

# %% [markdown]
# * Mapear a violência com armas de fogo no Brasil e sua relação com as políticas aramentistas do país ao longo dos anos, gerando assim arcabouço de iformações valiosas para a gestão pública na tomada de descisões mais inteligentes, visando uma redução na violência. Elaborar uma análise, sem viés político, sobre os impactos das políticas armamentistas no Brasil, desde a década de 90 até os dias até os dias de hoje.
#
# `Deste modo espera-se gerar insights que vão auxiliar o país na diminuição da violência por armas de fogo`
# <hr>

# %% [markdown]
# # <h2 id="3">3. Objetivos Específicos</h2>

# %% [markdown]
# * Minerar dados de fontes diversas para crianção de um conjunto de dados que dará origem ao nosso DataFrame;
# * Modelar os dados;
# * Analisar os dados;
# * Aplicar algoritmos de aprendizado de maquina para geração de predições;
# * Plotar apresentações gráficas e descritivas dos indicadores e insights para facilitar o entendimento;
# * Criar apresentação das informações em ferramenta externa (PowerBi ou Tableau)
# * Divulgar o estudo, de forma automática para os e-mails dos gabinetes de todos os deputados federais e senadores do Brasil.
# * Publicar em meios da comunicação - divulgar os resultados para a sociedade.
# <hr>

# %% [markdown]
# # <h2 id="2">4. Mineração de Dados - Criando Nosso Conjunto de Dados</h2>

# %% [markdown]
# * Nesta fase vamos trazer à nossa análise dados potencialmente pertinentes;
# * Posteriormente vamos organiza-los
# >// tem que por o numero de portes(registros)

# %% [markdown]
# Importando as bibliotecas pertinentes

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
def topo():
    print(33*'-')

# %% [markdown]
# ## Primeira Base de dados  [Atlas da Violência do IPEA](https://www.ipea.gov.br/atlasviolencia/)
# * O Atlas da Violência é um portal que reúne, organiza e disponibiliza informações sobre violência no Brasil, bem como reúne publicações do Ipea sobre violência e segurança pública. Foi criado em 2016 e é gerido pelo Instituto de Pesquisa Econômica Aplicada (Ipea) com a colaboração do Fórum Brasileiro de Segurança Pública (FBSP).

# %% [markdown]
# ## Entendendo os dados
#
# > df_obt_BR = Taxa de óbitos por armas de fogo a cada 100 mil habitantes Brasil 1989~2019.

# %%
df = pd.read_csv('taxa-de-homicidios-por-armas-de-fogo-BR.csv', sep=';', usecols=[1, 2, 3])
df.head(3)
# Out:
#   nome  período  valor
# 0  BRA     1989   9.51
# 1  BRA     1990  11.51
# 2  BRA     1991  10.73

# %%
# Dando uma olhada nos dados
display(df)
# Out:
#    nome  período  valor
# 0   BRA     1989   9.51
# 1   BRA     1990  11.51
# 2   BRA     1991  10.73
# 3   BRA     1992   9.94
# 4   BRA     1993  11.22
# 5   BRA     1994  12.29
# 6   BRA     1995  14.32
# 7   BRA     1996  14.63
# 8   BRA     1997  15.31
# 9   BRA     1998  15.87
# 10  BRA     1999  16.41
# 11  BRA     2000  18.58
# 12  BRA     2001  19.38
# 13  BRA     2002  19.56
# 14  BRA     2003  20.42
# 15  BRA     2004  18.83
# 16  BRA     2005  18.14
# 17  BRA     2006  18.70
# 18  BRA     2007  18.56
# 19  BRA     2008  18.82
# 20  BRA     2009  19.12
# 21  BRA     2010  19.29
# 22  BRA     2011  19.10
# 23  BRA     2012  20.66
# 24  BRA     2013  20.08
# 25  BRA     2014  21.08
# 26  BRA     2015  20.45
# 27  BRA     2016  21.58
# 28  BRA     2017  22.88
# 29  BRA     2018  19.75
# 30  BRA     2019  14.67

# %% [markdown]
# A primeira coisa que me salta aos olhos, é uma discrepância na varição dos dados de 2018 e 2019 em relação ao todo, vejamos o gráfico abaixo:

# %%
# Gráfico de destribuição de densidade em discos
# Separa os dados em grupos diferentes
sns.set_style('darkgrid')
x = df['período']
y = df['valor']
sns.displot(y=y, x=x, kind="kde", color='c', weights=7, height=7, rug=True)
plt.title('Gráfico de destribuição densidade em discos')
# Out:
# Text(0.5, 1.0, 'Gráfico de destribuição densidade em discos')

# %% [markdown]
# Como podemos visualizar melhor no gráfico acima, os dados de 2018 e 2019 estão fora do esperado, tendo em vista a série histórica de 31 anos apenas estes dois destoam.

# %% [markdown]
# Agora vamos criar uma nova coluna para quantificar esta discrepância nos dados que saltou aos olhos.
# A coluna `Discrepância` representará a variação da taxa em relação ao ano anterior.

# %%
# Inserindo uma coluna 'Discrepancia_Taxa' ao data frame
df.insert(3, 'Discrepancia_Taxa', 0)

# %%
# Calculando a Discrepancia_Taxa
for contador in range (1, 31): # Contador linha a linha começando a partir da segunda linha 
    minimo = min(df.iloc[contador, 2], df.iloc[(contador-1), 2]) # Calcula a menor taxa entre 2
    maximo = max(df.iloc[contador, 2], df.iloc[(contador-1), 2]) # Calcula a maior taxa entre 2
    df.at[contador, 'Discrepancia_Taxa'] = round((maximo - minimo), 2) # Define a diferença do maior pelo menor.
    if minimo == df.iloc[contador, 2]:
        df.at[contador, 'Discrepancia_Taxa'] *= -1
df.at[0, 'Discrepancia_Taxa'] = 0

# %% [markdown]
# Dando uma olhada no dataframe com a nova coluna `Discrepancia_Taxa`

# %%
display(df)
# Out:
#    nome  período  valor  Discrepancia_Taxa
# 0   BRA     1989   9.51               0.00
# 1   BRA     1990  11.51               2.00
# 2   BRA     1991  10.73              -0.78
# 3   BRA     1992   9.94              -0.79
# 4   BRA     1993  11.22               1.28
# 5   BRA     1994  12.29               1.07
# 6   BRA     1995  14.32               2.03
# 7   BRA     1996  14.63               0.31
# 8   BRA     1997  15.31               0.68
# 9   BRA     1998  15.87               0.56
# 10  BRA     1999  16.41               0.54
# 11  BRA     2000  18.58               2.17
# 12  BRA     2001  19.38               0.80
# 13  BRA     2002  19.56               0.18
# 14  BRA     2003  20.42               0.86
# 15  BRA     2004  18.83              -1.59
# 16  BRA     2005  18.14              -0.69
# 17  BRA     2006  18.70               0.56
# 18  BRA     2007  18.56              -0.14
# 19  BRA     2008  18.82               0.26
# 20  BRA     2009  19.12               0.30
# 21  BRA     2010  19.29               0.17
# 22  BRA     2011  19.10              -0.19
# 23  BRA     2012  20.66               1.56
# 24  BRA     2013  20.08              -0.58
# 25  BRA     2014  21.08               1.00
# 26  BRA     2015  20.45              -0.63
# 27  BRA     2016  21.58               1.13
# 28  BRA     2017  22.88               1.30
# 29  BRA     2018  19.75              -3.13
# 30  BRA     2019  14.67              -5.08

# %% [markdown]
# Plotando um gráfico para melhor visualização da discrepância ano a ano.

# %%
plt.subplots(figsize=(16, 10))
x = df['período']
y = df['Discrepancia_Taxa']
grafico = sns.barplot(x=x, y=y, palette='Blues_d')
pd.set_option('display.precision', 2)
for item in grafico.patches:
    grafico.annotate(
                     item.get_height(),
                     (item.get_x() + item.get_width() /2, item.get_height()),
                      ha='center',
                      rotation=90,
                      va='baseline',
                      fontsize=13,
                      color='black',
                      xytext=(0, 0),
                      textcoords='offset points',
                      )

# %% [markdown]
# Podemos verificar que existem valores destoantes na amostra
# >Principais possibilidades:
# * Inconssistência nos dados
# * Maquiagem nos dados
# * Grande variação nos dados por algum motivo ainda desconhecido.
# >Posteriormente trataremos esta informação
# <hr>

# %% [markdown]
# ## Ainda dentro do supracitado Atlas da violência do Ipea, traremos agora outros elementos para nossa análise.

# %% [markdown]
# Vamos trazer pro nosso conjunto de dados agora, o número da quantidade total de homicídios por arma de fogo, ano a ano, nível Brasil [Fonte](https://www.ipea.gov.br/atlasviolencia/filtros-series/5/bitos-por-armas-de-fogo)

# %%
df_auxiliar = pd.read_csv('total-homicidios-por-armas-de-fogo-BR.csv', sep=';')
df_auxiliar.head(5)
# Out:
#     cod nome  período  valor
# 0  1076  BRA     1989  13480
# 1  1076  BRA     1990  16588
# 2  1076  BRA     1991  15759
# 3  1076  BRA     1992  14785
# 4  1076  BRA     1993  17002

# %%
# Inserindo uma coluna 'Fatalidades_Totais' com o valor correto ao data frame
df.insert(4, 'Fatalidades_Totais', df_auxiliar['valor'].copy())

# %%
# Verificando se a inclusão dos dados obteve êxito/ dando uma oolhada nos dados
df
# Out:
#    nome  período  valor  Discrepancia_Taxa  Fatalidades_Totais
# 0   BRA     1989   9.51               0.00               13480
# 1   BRA     1990  11.51               2.00               16588
# 2   BRA     1991  10.73              -0.78               15759
# 3   BRA     1992   9.94              -0.79               14785
# 4   BRA     1993  11.22               1.28               17002
# 5   BRA     1994  12.29               1.07               18889
# 6   BRA     1995  14.32               2.03               22306
# 7   BRA     1996  14.63               0.31               22976
# 8   BRA     1997  15.31               0.68               24445
# 9   BRA     1998  15.87               0.56               25674
# 10  BRA     1999  16.41               0.54               26902
# 11  BRA     2000  18.58               2.17               30865
# 12  BRA     2001  19.38               0.80               33401
# 13  BRA     2002  19.56               0.18               34160
# 14  BRA     2003  20.42               0.86               36115
# 15  BRA     2004  18.83              -1.59               34187
# 16  BRA     2005  18.14              -0.69               33419
# 17  BRA     2006  18.70               0.56               34921
# 18  BRA     2007  18.56              -0.14               34147
# 19  BRA     2008  18.82               0.26               35676
# 20  BRA     2009  19.12               0.30               36624
# 21  BRA     2010  19.29               0.17               36792
# 22  BRA     2011  19.10              -0.19               36737
# 23  BRA     2012  20.66               1.56               40077
# 24  BRA     2013  20.08              -0.58               40369
# 25  BRA     2014  21.08               1.00               42755
# 26  BRA     2015  20.45              -0.63               41817
# 27  BRA     2016  21.58               1.13               44475
# 28  BRA     2017  22.88               1.30               47510
# 29  BRA     2018  19.75              -3.13               41179
# 30  BRA     2019  14.67              -5.08               30206

# %% [markdown]
# Agora vamos fazer uma validação dos dados, inserindo uma coluna com a discrepância total e verificando se bate com a nossa coluna de discrepância de taxa, verificando assim confiabilidade entre os dados totais e a taxa a cada 100k habitantes:

# %%
# Inserindo uma coluna 'Discrepancia_Qtd_Total' ao data frame
df.insert(5, 'Discrepancia_Qtd_Total', 0)

# %%
for contador in range (1, 31): # Contador linha a linha começando a partir da segunda linha 
    minimo = min(df.iloc[contador, 2], df.iloc[(contador-1), 2]) # Calcula a menor taxa entre 2
    maximo = max(df.iloc[contador, 2], df.iloc[(contador-1), 2]) # Calcula a maior taxa entre 2
    df.at[contador, 'Discrepancia_Qtd_Total'] = round((maximo - minimo), 2) # Define a diferença do maior pelo menor.
    if minimo == df.iloc[contador, 2]:
        df.at[contador, 'Discrepancia_Qtd_Total'] *= -1
df.at[0, 'Discrepancia_Qtd_Total'] = 0

# %%
# Validando os dados
df['Discrepancia_Taxa'] == df['Discrepancia_Qtd_Total']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# dtype: bool

# %% [markdown]
# > Relação entre fatalidades totais e taxa a cada 100k habitantes `validada com sucesso`.

# %% [markdown]
# Agora vamos deletar a coluna redundante

# %%
# Descarta os valores passados
df.drop(columns=['Discrepancia_Qtd_Total'], inplace=True)
df.columns
# Out:
# Index(['nome', 'período', 'valor', 'Discrepancia_Taxa', 'Fatalidades_Totais'], dtype='object')

# %% [markdown]
# Outro dado que traremos para nossa análise, ainda extraido do  `Atlas da Violência do Ipea` será a `Taxa de homicídios por arma de fogo a cada 100k habitantes por estados` [Fonte](https://www.ipea.gov.br/atlasviolencia/filtros-series/5/bitos-por-armas-de-fogo)

# %% [markdown]
# Criando df_UF com a taxa supracitada

# %%
df_UF = pd.read_csv('taxa-de-homicídios-por-armas-de-fogo-UF.csv', sep=';', usecols=[1, 2, 3])
pd.set_option('display.max_rows', 33)
df_UF
# Out:
#     nome  período  valor
# 0     RO     1989  29.07
# 1     AC     1989  13.88
# 2     AM     1989   7.88
# 3     RR     1989   0.52
# 4     PA     1989   8.21
# ..   ...      ...    ...
# 832   RS     2019  14.26
# 833   MS     2019   8.82
# 834   MT     2019  14.21
# 835   GO     2019  22.84
# 836   DF     2019   8.76
#
# [837 rows x 3 columns]

# %%
# Renomeando títulos das colunas
df_UF.columns=['UF', 'Ano', 'Taxa_Fatalidades']
df_UF.head(1)
# Out:
#    UF   Ano  Taxa_Fatalidades
# 0  RO  1989             29.07

# %%
# Renomeando títulos das colunas
df.rename(columns={'nome':'Pais'},inplace=True)
df.rename(columns={'período':'Ano'},inplace=True)
df.rename(columns={'valor':'Taxa_Fatalidades'},inplace=True)
df.head(1)
# Out:
#   Pais   Ano  Taxa_Fatalidades  Discrepancia_Taxa  Fatalidades_Totais
# 0  BRA  1989              9.51                0.0               13480

# %%
# Verificando quantidade de estados (Brasil tem 26 mais DF)
df_UF['UF'].nunique()
# Out:
# 27

# %% [markdown]
# > Dados validados
# <hr>

# %% [markdown]
# Criando uma nova coluna `Politica_Publica` [`armamento`/`desarmamento`] nos 2 conjuntos de dados atuais, essa coluna informará se no ano em questão, a política pública foi favorável ou armamento ou ao desarmamento.

# %%
# Inserindo uma coluna 'Discrepancia_Qtd_Total' ao data frame
df.insert(2, 'Politica_Publica', '')
df.head(1)
# Out:
#   Pais   Ano Politica_Publica  Taxa_Fatalidades  Discrepancia_Taxa  \
# 0  BRA  1989                               9.51                0.0
#
#    Fatalidades_Totais
# 0               13480

# %%
# Preenchendo os dados
for contador in range(0, len(df)): # Contador linha a linha 
    if df.iloc[contador, 1] <= 2003:
        df.at[contador, 'Politica_Publica'] = 'Armamento'
    elif df.iloc[contador, 1] < 2019:
        df.at[contador, 'Politica_Publica'] = 'Desarmamento'
    else:
        df.at[contador, 'Politica_Publica'] = 'Armamento'
for contador in range(0, len(df_UF)): # Contador lina a linha no dataframe UF
    if df_UF.iloc[contador, 1] <= 2003:
        df_UF.at[contador, 'Politica_Publica'] = 'Armamento'
    elif df_UF.iloc[contador, 1] < 2019:
        df_UF.at[contador, 'Politica_Publica'] = 'Desarmamento'
    else:
        df_UF.at[contador, 'Politica_Publica'] = 'Armamento'

# %%
df.head(5) # verificando como ficou
# Out:
#   Pais   Ano Politica_Publica  Taxa_Fatalidades  Discrepancia_Taxa  \
# 0  BRA  1989        Armamento              9.51               0.00
# 1  BRA  1990        Armamento             11.51               2.00
# 2  BRA  1991        Armamento             10.73              -0.78
# 3  BRA  1992        Armamento              9.94              -0.79
# 4  BRA  1993        Armamento             11.22               1.28
#
#    Fatalidades_Totais
# 0               13480
# 1               16588
# 2               15759
# 3               14785
# 4               17002

# %% [markdown]
# >Coluna `Politica_Publica` ok

# %% [markdown]
# ## Agora, para nosso `DataSet` ficar mais robusto, vamos minerar mais dados. É interessante para nossa análise, trazer o número de registros de armas de fogo no Brasil ano a ano, então fui atrás destes dados.

# %% [markdown]
# ### Entendendo os dados
#
# #### `Registros-Armas.xlsx`:
#
#
# Realizei consultas em diversas fontes e consegui minerar e tabular o seguinte conjunto de dados;
#
# Quanto mais nos afastamos na linha do tempo, mais escassos ficaram os dados, posteriormente decidiremos o que fazer com os dados que estão faltando.
#
# Agora vamos entender cada coluna deste novo dataset:
#
#
# *   **Obs** - Observações sobre fatos importantes ocorridos no ano;
# *   **Ano** - 1998~2021 - Refere-se ao ano do registro;
# *   **Novos Registros** - Refere-se ao total absoluto de **novos registros de arma de fogo** feitos junto a PF e o Exército Brasileito no ano em questão;
# *   **Total Armas Registradas** - Refere-se ao **número total** de armas em circulação no ano;
# *   **Novos Cacs** - Refere-se ao número de novos registros CACs no ano. É importante destacar que a PF faz o registro das armas usadas por civis, como servidores públicos com porte funcional,  mpresas de segurança privada e cidadãos comuns, entre outras categorias. E cabe ao Exército fazer o controle de armas de militares e de caçadores, atiradores e colecionadores (CACs)
# *  **Fonte** - Fontes dos dados da linha.

# %%
df_auxiliar = pd.read_excel('Registros-Armas.xlsx') # Importando novo conjunto de dados:
df_auxiliar.head(5) # Dando uma olhada nos dados novos
# Out:
#    Obs   Ano  Novos Registros  Total Armas Registradas  Novos Cacs  \
# 0  NaN  2021         204300.0                 1.50e+06         NaN
# 1  NaN  2020          17782.0                 1.28e+06    286900.0
# 2  NaN  2019          94064.0                 1.06e+06    200100.0
# 3  NaN  2018          51018.0                      NaN         NaN
# 4  NaN  2017          33031.0                 6.38e+05     14024.0
#
#                                                Fonte  \
# 0  https://www.istoedinheiro.com.br/registro-de-a...
# 1  https://www.istoedinheiro.com.br/registro-de-a...
# 2  https://www.istoedinheiro.com.br/registro-de-a...
# 3                                                NaN
# 4  https://g1.globo.com/sp/sao-paulo/noticia/2021...
#
#                                              Fonte.1  \
# 0                                                NaN
# 1  https://g1.globo.com/sp/sao-paulo/noticia/2021...
# 2  https://www.poder360.com.br/brasil/novos-regis...
# 3                                                NaN
# 4  https://noticias.uol.com.br/cotidiano/ultimas-...
#
#                                              Fonte.2
# 0                                                NaN
# 1                                                NaN
# 2  https://g1.globo.com/sp/sao-paulo/noticia/2021...
# 3                                                NaN
# 4                                                NaN

# %%
# Trazendo os conjunto de dados dados para nosso dataframe principal
df.insert(1, 'Obs', df_auxiliar['Obs'])
df.insert(7, 'Novos Registros', df_auxiliar['Novos Registros'])
df.insert(8, 'Total Armas Registradas', df_auxiliar['Total Armas Registradas'])
df.insert(9, 'Novos Cacs', df_auxiliar['Novos Cacs'])

# %%
# Verificando se os dados foram alocados corretamentes no nosso dataframe original
df.head(3)
# Out:
#   Pais  Obs   Ano Politica_Publica  Taxa_Fatalidades  Discrepancia_Taxa  \
# 0  BRA  NaN  1989        Armamento              9.51               0.00
# 1  BRA  NaN  1990        Armamento             11.51               2.00
# 2  BRA  NaN  1991        Armamento             10.73              -0.78
#
#    Fatalidades_Totais  Novos Registros  Total Armas Registradas  Novos Cacs
# 0               13480         204300.0                 1.50e+06         NaN
# 1               16588          17782.0                 1.28e+06    286900.0
# 2               15759          94064.0                 1.06e+06    200100.0

# %% [markdown]
# >Dados alocados com sucesso

# %% [markdown]
# ## Quais outras váriaveis se relacionam com os efeitos da violência por armas?
#
# *  Assaltos a residência;
# *  Feminicídios;
# *  Mortes decorrentes de ações policiais;
# *  Motivações dos homicídios por arma de fogo;

# %% [markdown]
# ## Agora vamos minerar os dados supracitados

# %% [markdown]
# Acessamos o [Fórum Brasileiro de Segurança Pública](https://forumseguranca.org.br/) e lá acessamos o [Anuário Brasileiro de Segurança Pública](https://forumseguranca.org.br/anuario-brasileiro-seguranca-publica/)
#
# * Clique nos links acima para saber mais sobre o Fórum e o Anuário;
# * Os anuários estão disponíveis desde 2007(1º anuário) até 2021(15º anuário);
# * Os anuários tem um grande volume de dados, são disponibilizados em formato .xlxs(EXCEL), tendo aproximadamente 330 abas diferentes em cada arquivo
# * Temos uma base de dados em excel com aproximadamente 5 mil abas para filtrarmos.
# [Link dos anuários](https://forumseguranca.org.br/wp-content/uploads/2021/10/anuario-15-completo-v6-251021.xlsx)

# %% [markdown]
# > Em desenvolvimento
# <hr>

# %% [markdown]
# > Rascunho Machine Learning

# %% [markdown]
# Agora vamos:
# * Utilizar a bilioteca scikit-learn para implantar um modelo de regressão linear simples;
# * Criar um modelo, treina-lo, testa-lo e utilizar.

# %% [markdown]
# Primeiramente vamos separar alguma característica para aprofundar

# %%
df
# Out:
#    Pais                                                Obs   Ano  \
# 0   BRA                                                NaN  1989
# 1   BRA                                                NaN  1990
# 2   BRA                                                NaN  1991
# 3   BRA                                                NaN  1992
# 4   BRA                                                NaN  1993
# 5   BRA                                                NaN  1994
# 6   BRA  estatuto do desarmamento foi revogado pela cam...  1995
# 7   BRA                                                NaN  1996
# 8   BRA                                                NaN  1997
# 9   BRA                                                NaN  1998
# 10  BRA                                                NaN  1999
# 11  BRA                                                NaN  2000
# 12  BRA                                                NaN  2001
# 13  BRA                                                NaN  2002
# 14  BRA      reducao de homicidios em SP de 60% desde 2001  2003
# 15  BRA                                                NaN  2004
# 16  BRA                                                NaN  2005
# 17  BRA                                                NaN  2006
# 18  BRA                           promulugacao do estatuto  2007
# 19  BRA                                                NaN  2008
# 20  BRA  de 2001 a 2007 politica de desarmamento estado...  2009
# 21  BRA                                                NaN  2010
# 22  BRA                                                NaN  2011
# 23  BRA                                                NaN  2012
# 24  BRA                                                NaN  2013
# 25  BRA                                                NaN  2014
# 26  BRA                                                NaN  2015
# 27  BRA                                                NaN  2016
# 28  BRA                                                NaN  2017
# 29  BRA                                                NaN  2018
# 30  BRA                                                NaN  2019
#
#    Politica_Publica  Taxa_Fatalidades  Discrepancia_Taxa  Fatalidades_Totais  \
# 0         Armamento              9.51               0.00               13480
# 1         Armamento             11.51               2.00               16588
# 2         Armamento             10.73              -0.78               15759
# 3         Armamento              9.94              -0.79               14785
# 4         Armamento             11.22               1.28               17002
# 5         Armamento             12.29               1.07               18889
# 6         Armamento             14.32               2.03               22306
# 7         Armamento             14.63               0.31               22976
# 8         Armamento             15.31               0.68               24445
# 9         Armamento             15.87               0.56               25674
# 10        Armamento             16.41               0.54               26902
# 11        Armamento             18.58               2.17               30865
# 12        Armamento             19.38               0.80               33401
# 13        Armamento             19.56               0.18               34160
# 14        Armamento             20.42               0.86               36115
# 15     Desarmamento             18.83              -1.59               34187
# 16     Desarmamento             18.14              -0.69               33419
# 17     Desarmamento             18.70               0.56               34921
# 18     Desarmamento             18.56              -0.14               34147
# 19     Desarmamento             18.82               0.26               35676
# 20     Desarmamento             19.12               0.30               36624
# 21     Desarmamento             19.29               0.17               36792
# 22     Desarmamento             19.10              -0.19               36737
# 23     Desarmamento             20.66               1.56               40077
# 24     Desarmamento             20.08              -0.58               40369
# 25     Desarmamento             21.08               1.00               42755
# 26     Desarmamento             20.45              -0.63               41817
# 27     Desarmamento             21.58               1.13               44475
# 28     Desarmamento             22.88               1.30               47510
# 29     Desarmamento             19.75              -3.13               41179
# 30        Armamento             14.67              -5.08               30206
#
#     Novos Registros  Total Armas Registradas  Novos Cacs
# 0          204300.0                 1.50e+06         NaN
# 1           17782.0                 1.28e+06    286900.0
# 2           94064.0                 1.06e+06    200100.0
# 3           51018.0                      NaN         NaN
# 4           33031.0                 6.38e+05     14024.0
# 5               NaN                      NaN     20575.0
# 6           36807.0                      NaN      7215.0
# 7           24534.0                      NaN      5132.0
# 8           19947.0                      NaN      7360.0
# 9           19552.0                      NaN         NaN
# 10          15240.0                      NaN         NaN
# 11          12006.0                      NaN         NaN
# 12           8679.0                      NaN         NaN
# 13           6301.0                      NaN         NaN
# 14           3938.0                      NaN         NaN
# 15           4778.0                      NaN         NaN
# 16           4288.0                      NaN         NaN
# 17           3055.0                      NaN         NaN
# 18              NaN                      NaN         NaN
# 19              NaN                 4.66e+06         NaN
# 20              NaN                      NaN         NaN
# 21              NaN                      NaN         NaN
# 22              NaN                      NaN         NaN
# 23              NaN                      NaN         NaN
# 24              NaN                      NaN         NaN
# 25              NaN                      NaN         NaN
# 26              NaN                      NaN         NaN
# 27              NaN                      NaN         NaN
# 28              NaN                      NaN         NaN
# 29              NaN                      NaN         NaN
# 30              NaN                      NaN         NaN

# %% [markdown]
# >ABAIXO É RASCUNHO

# %% [markdown]
# ## Trazendo mais dados para nosssa análise.

# %% [markdown]
# Acessamos o [Fórum Brasileiro de Segurança Pública](https://forumseguranca.org.br/) e lá acessamos o [Anuário Brasileiro de Segurança Pública](https://forumseguranca.org.br/anuario-brasileiro-seguranca-publica/)
#
# * Clique nos links acima para saber mais sobre o Fórum e o Anuário;
# * Os anuários estão disponíveis desde 2007(1º anuário) até 2021(15º anuário);
# * Os anuários tem um grande volume de dados, são disponibilizados em formato .xlxs(EXCEL), tendo aproximadamente 330 abas diferentes em cada arquivo
# * Temos uma base de dados em excel com aproximadamente 5 mil abas filtrarmos.
# [Link dos anuários](https://forumseguranca.org.br/wp-content/uploads/2021/10/anuario-15-completo-v6-251021.xlsx)

# %% [markdown]
# >Vamos eleger alguns dados chave, de importância estratégica para trazermos ao nosso conjunto de dados.

# %% [markdown]
# ## Outras potenciais fontes de dados:
# * Ocorrências Criminais - Sinesp https://dados.gov.br/dataset/sistema-nacional-de-estatisticas-de-seguranca-publica
#
# * SINARM - Sistema Nacional de Armas https://dados.gov.br/dataset/sinarm
# https://servicos.dpf.gov.br/dadosabertos/SINARM/

# %% [markdown]
# Podemos observar que estão faltando os valores de 2020, 2021 então vamos buscar em outras fontes.

# %% [markdown]
# >O Estatuto do Desarmamento é uma política de controle de armas que entrou em vigor no Brasil por meio de lei no dia 22 de dezembro de 2003. Ele foi sancionado com o objetivo de reduzir a circulação de armas e estabelecer penas mais rigorosas para crimes. [Fonte](https://www.brasilparalelo.com.br/artigos/desarmamento-no-brasil#:~:text=O%20Estatuto%20do%20Desarmamento%20%C3%A9,mais%20rigorosas%20para%20crimes%20relacionados.)
# * Logo de 2004 até 2019 houveram políticas de desarmamento
#
# >Em 2019 Jair Bolsonaro assumiu e já em janeiro, assinou decreto que facilitou a compra de armas. [Fonte](https://g1.globo.com/politica/noticia/2019/01/15/bolsonaro-assina-decreto-que-facilita-posse-de-armas.ghtml)
# * Logo de 2019 até 2022 houveram políticas favoráveis ao armamento. [fonte](https://g1.globo.com/politica/noticia/2019/01/15/bolsonaro-assina-decreto-que-facilita-posse-de-armas.ghtml)

# %% [markdown]
# <hr>

# %%
cdf = df[['Ano', 'Fatalidades_Totais']].copy()  #Afunilando

# %%
cdf.drop(axis=0, index=[29,30], inplace=True) # Dropando colunar foras da normalidade

# %% [markdown]
# plt.scatter(cdf.Consumo_combo, cdf.EmissaoCO2,  color='blue')
# plt.xlabel("Consumo de combustível combo")
# plt.ylabel("Emissão de CO2")
# plt.title("Consumo x Emissão")
# plt.show()

# %%
plt.scatter(cdf.Ano, cdf.Fatalidades_Totais,  color='blue')
plt.xlabel("Ano")
plt.ylabel("Número Total de Fatalidades")
plt.title("Ano x Total de Fatalidades")
plt.show()

# %% [markdown]
# #### Criando um conjunto de dados de treino e teste
#
#
# A divisão de treinamento/teste envolve a divisão do conjunto de dados em conjuntos de treinamento e teste que são mutuamente exclusivos. Depois disso, você treina com o conjunto de treinamento e testa com o conjunto de teste.
# Isso fornecerá uma avaliação mais precisa da precisão fora da amostra porque o conjunto de dados de teste não faz parte do conjunto de dados que foi usado para treinar o modelo. Portanto, isso nos dá uma melhor compreensão de quão bem nosso modelo generaliza em novos dados.
#
# Isso significa que sabemos o resultado de cada ponto de dados no conjunto de dados de teste, tornando-o ótimo para testar! Como esses dados não foram usados ​​para treinar o modelo, o modelo não tem conhecimento do resultado desses pontos de dados. Então, em essência, é realmente um teste fora da amostra.
#
# Vamos dividir nosso conjunto de dados em conjuntos de treinamento e teste. 80% de todo o conjunto de dados será usado para treinamento e 20% para teste. Criamos uma máscara para selecionar linhas aleatórias usando a função **np.random.rand()**:

# %%
msk = np.random.rand(len(cdf)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %% [markdown]
# ### Modelo de regressão simples
#
# A Regressão Linear ajusta um modelo linear com coeficientes B = (B1, ..., Bn) para minimizar a 'soma dos quadrados residual' entre o valor real  no conjunto de dados e o valor previsto usando aproximação linear.

# %% [markdown]
# Destribuição do treino de dados:

# %%
plt.scatter(train.Ano, train.Fatalidades_Totais,  color='blue')
plt.xlabel("Ano")
plt.ylabel("Fatalidades Totais")
plt.show()

# %% [markdown]
# Usando sklearn para modelar os dados

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression() # Modelo de regressão linear simples
train_x = np.asanyarray(train[['Ano']])
train_y = np.asanyarray(train[['Fatalidades_Totais']])
regr.fit(train_x, train_y)
# Gradiente angular
print ('Gradiente Angular: ', regr.coef_)
print ('Intersecção: ',regr.intercept_)
# Out:
# Gradiente Angular:  [[1096.09590044]]
# Intersecção:  [-2164777.34699854]

# %% [markdown]
# Hipótese

# %%
plt.scatter(train.Ano, train.Fatalidades_Totais,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Ano")
plt.ylabel("Total de Fatalidades no Brasil")
# Out:
# Text(0, 0.5, 'Total de Fatalidades no Brasil')

# %% [markdown]
# #### Avaliação de precisão da nossa hipótese
#
# Comparamos os valores reais e os valores previstos para calcular a precisão de um modelo de regressão. As métricas de avaliação desempenham um papel fundamental no desenvolvimento de um modelo, pois fornecem insights para áreas que precisam ser aprimoradas.
#
# Existem diferentes métricas de avaliação do modelo, vamos usar o **MSE(EMA)** aqui para calcular a precisão do nosso modelo com base no conjunto de teste:
#
# * **Erro Médio Absoluto**: É a média do valor absoluto dos erros. Essa é a métrica mais fácil de entender, pois é apenas um erro médio.
#
# * **Erro quadrático médio (MSE)**: Erro quadrático médio (MSE) é a média do erro quadrático. É mais popular que o erro médio absoluto porque o foco é mais voltado para erros grandes. Isso se deve ao fato de o termo quadrado aumentar exponencialmente os erros maiores em comparação com os menores.
#
# * **Erro quadrático médio da raiz (RMSE)**.
#
# * **R²** não é um erro, mas sim uma métrica popular para medir o desempenho do seu modelo de regressão. Ele representa o quão perto os pontos de dados estão da linha de regressão ajustada. Quanto maior o valor do R-quadrado, melhor o modelo se ajusta aos seus dados. A melhor pontuação possível é 1,0 e pode ser negativa (porque o modelo pode ser arbitrariamente pior).

# %%
from sklearn.metrics import r2_score
test_x = np.asanyarray(test[['Ano']])
test_y = np.asanyarray(test[['Fatalidades_Totais']])
test_y_ = regr.predict(test_x)



topo()
print('Avaliação de erro em relação ao tamanho do motor')
topo()
print(f"Média de erro absoluta(MAE): {np.mean(np.absolute(test_y_ - test_y)):.2f}")
print(f"Residual da soma dos quadrados(MSE): {np.mean((test_y_ - test_y) ** 2):.2f} ")
print(f"R²: {r2_score(test_y , test_y_):.2f}")
topo()
# Out:
# ---------------------------------
# Avaliação de erro em relação ao tamanho do motor
# ---------------------------------
# Média de erro absoluta(MAE): 1601.33
# Residual da soma dos quadrados(MSE): 6436167.95
# R²: 0.90
# ---------------------------------

# %% [markdown]
# <hr>

# %%
plt.subplots(figsize=(16, 8))
x = df['Ano']
y = df['Taxa_Fatalidades']
plt.xticks(rotation=90)
plt.title('Taxa de homicídios a cada 100k habitantes Brasil')


cores = []
for ano in df['Ano']: 
    if ano <= 2003:
       cores.append('green')
    elif ano <= 2018:
        cores.append('red')
    else:
        cores.append('green')
print(cores)



grafico = sns.barplot(x=x, y=y, palette=cores)
pd.set_option('display.precision', 2)
for item in grafico.patches:
    grafico.annotate(
                     item.get_height(),
                     (item.get_x() + item.get_width() /2, item.get_height()),
                      ha='center',
                      rotation=90,
                      va='baseline',
                      fontsize=13,
                      color='white',
                      xytext=(0, -33),
                      textcoords='offset points',
                      )
# Out:
# ['green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'green']

# %%
df
# Out:
#    Pais                                                Obs   Ano  \
# 0   BRA                                                NaN  1989
# 1   BRA                                                NaN  1990
# 2   BRA                                                NaN  1991
# 3   BRA                                                NaN  1992
# 4   BRA                                                NaN  1993
# 5   BRA                                                NaN  1994
# 6   BRA  estatuto do desarmamento foi revogado pela cam...  1995
# 7   BRA                                                NaN  1996
# 8   BRA                                                NaN  1997
# 9   BRA                                                NaN  1998
# 10  BRA                                                NaN  1999
# 11  BRA                                                NaN  2000
# 12  BRA                                                NaN  2001
# 13  BRA                                                NaN  2002
# 14  BRA      reducao de homicidios em SP de 60% desde 2001  2003
# 15  BRA                                                NaN  2004
# 16  BRA                                                NaN  2005
# 17  BRA                                                NaN  2006
# 18  BRA                           promulugacao do estatuto  2007
# 19  BRA                                                NaN  2008
# 20  BRA  de 2001 a 2007 politica de desarmamento estado...  2009
# 21  BRA                                                NaN  2010
# 22  BRA                                                NaN  2011
# 23  BRA                                                NaN  2012
# 24  BRA                                                NaN  2013
# 25  BRA                                                NaN  2014
# 26  BRA                                                NaN  2015
# 27  BRA                                                NaN  2016
# 28  BRA                                                NaN  2017
# 29  BRA                                                NaN  2018
# 30  BRA                                                NaN  2019
#
#    Politica_Publica  Taxa_Fatalidades  Discrepancia_Taxa  Fatalidades_Totais  \
# 0         Armamento              9.51               0.00               13480
# 1         Armamento             11.51               2.00               16588
# 2         Armamento             10.73              -0.78               15759
# 3         Armamento              9.94              -0.79               14785
# 4         Armamento             11.22               1.28               17002
# 5         Armamento             12.29               1.07               18889
# 6         Armamento             14.32               2.03               22306
# 7         Armamento             14.63               0.31               22976
# 8         Armamento             15.31               0.68               24445
# 9         Armamento             15.87               0.56               25674
# 10        Armamento             16.41               0.54               26902
# 11        Armamento             18.58               2.17               30865
# 12        Armamento             19.38               0.80               33401
# 13        Armamento             19.56               0.18               34160
# 14        Armamento             20.42               0.86               36115
# 15     Desarmamento             18.83              -1.59               34187
# 16     Desarmamento             18.14              -0.69               33419
# 17     Desarmamento             18.70               0.56               34921
# 18     Desarmamento             18.56              -0.14               34147
# 19     Desarmamento             18.82               0.26               35676
# 20     Desarmamento             19.12               0.30               36624
# 21     Desarmamento             19.29               0.17               36792
# 22     Desarmamento             19.10              -0.19               36737
# 23     Desarmamento             20.66               1.56               40077
# 24     Desarmamento             20.08              -0.58               40369
# 25     Desarmamento             21.08               1.00               42755
# 26     Desarmamento             20.45              -0.63               41817
# 27     Desarmamento             21.58               1.13               44475
# 28     Desarmamento             22.88               1.30               47510
# 29     Desarmamento             19.75              -3.13               41179
# 30        Armamento             14.67              -5.08               30206
#
#     Novos Registros  Total Armas Registradas  Novos Cacs
# 0          204300.0                 1.50e+06         NaN
# 1           17782.0                 1.28e+06    286900.0
# 2           94064.0                 1.06e+06    200100.0
# 3           51018.0                      NaN         NaN
# 4           33031.0                 6.38e+05     14024.0
# 5               NaN                      NaN     20575.0
# 6           36807.0                      NaN      7215.0
# 7           24534.0                      NaN      5132.0
# 8           19947.0                      NaN      7360.0
# 9           19552.0                      NaN         NaN
# 10          15240.0                      NaN         NaN
# 11          12006.0                      NaN         NaN
# 12           8679.0                      NaN         NaN
# 13           6301.0                      NaN         NaN
# 14           3938.0                      NaN         NaN
# 15           4778.0                      NaN         NaN
# 16           4288.0                      NaN         NaN
# 17           3055.0                      NaN         NaN
# 18              NaN                      NaN         NaN
# 19              NaN                 4.66e+06         NaN
# 20              NaN                      NaN         NaN
# 21              NaN                      NaN         NaN
# 22              NaN                      NaN         NaN
# 23              NaN                      NaN         NaN
# 24              NaN                      NaN         NaN
# 25              NaN                      NaN         NaN
# 26              NaN                      NaN         NaN
# 27              NaN                      NaN         NaN
# 28              NaN                      NaN         NaN
# 29              NaN                      NaN         NaN
# 30              NaN                      NaN         NaN

# %% [markdown]
# <hr>
# RASCUNHO:

# %% [markdown]
# >Isso coloca quando começarmos a análise de dados.
#
# Vários autores procuram evidenciar a relação causal entre mais armas e mais crimes,
# entre os quais Duggan (2001), Sherman, Shaw e Rogan (1995), Stolzenberg e D´Alessio
# (2000), McDowall (1991), McDowall, Loftin e Wiersema (1995), Cook e Ludwig (1998,
# 2002), Sloan et al. (1988), Ludwig (1998) e Newton e Zimring (1969). Geralmente os
# argumentos utilizados nestes artigos são os seguintes: i) o indivíduo que possui uma arma
# de fogo fica encorajado a dar respostas violentas para a solução de conflitos interpessoais;
# ii) o possuidor de armas fica com poder para coagir; iii) do ponto de vista do criminoso, a
# posse da arma de fogo faz aumentar a produtividade e diminuir o risco de o perpetrador
# cometer crimes; e iv) o aumento da facilidade e do acesso às armas significa diminuição
# do custo da arma pelo criminoso no mercado ilegal.
#
# Entretanto, a conclusão de vários trabalhos – entre os quais Bronars e Lott Junior
# (1998), Lott Junior e Mustard (1997), Kleck (1979) e Bartley e Cohen (1998) – é de
# que mais armas significam menos crimes. Segundo estes autores, a difusão de armas na
# população faria diminuir a taxa de crimes (pelo menoção de armas de fogo (KLECK, 1979). Em muitos outros trabalhos, sequer se utilizou
# uma medida de prevalência das armas de fogo, e a estratégia de identificação geralmente se baseou na análise da variação da taxa de crimes em cidades e estados americanos
# em que houve ou não mudança na legislação sobre o tema (aprovação do sistema de
# shall issue, conforme será visto adiante). Contudo, é bastante questionável interpretar
# uma mudança de lei como uma variação exógena, se esta mudança ocorreu apenas em
# alguns estados da base de dados, possivelmente como consequência da alta criminalidade nestas localidades. Por sua vez, o problema de variáveis omitidas permanece como
# uma questão central a ser trabalhada dentro das estratégias de identificação utilizadas
# para captar o efeito da mudança de legislação.s os crimes contra o patrimônio),
# uma vez que o uso defensivo da arma de fogo pelas potenciais vítimas faria aumentar o
# custo esperado para o perpetrador cometer crimes.
#
# A despeito dos inúmeros artigos sobre o tema, não se alcançou ainda um consenso acerca do efeito causal entre armas de fogo e aumento da criminalidade. Possivelmente isto decorre das dificuldades metodológicas envolvidas, que passam pela
# busca por uma medida confiável de prevalência de armas de fogo nas cidades, além dos
# clássicos problemas de simultaneidade e de variáveis omitidas. Por exemplo, alguns autores utilizaram proxies de validade bastante discutível para o estoque de armas de fogo
# nas localidades, como o número de revistas especializadas em armas de fogo vendidas1
# (MOODY e MARVELL, 2002; DUGGAN, 2001), ou mesmo a produção e importa
#
# Dados semelhantes foram apresentados pelo sociólogo Guaracy Mingardi em uma pesquisa em 1996 que revelou que 46% dos casos de homicídio registrados na Zona Sul da capital, vítima e autor mantinham uma relação prévia de parentesco, vizinhança, amizade, ou outra proximidade qualquer. Esses dados apontam para o fato de que nós nos matamos em situações mundanas, como uma briga de trânsito, uma discussão com o vizinho, um mal-entendido no bar ou um desentendimento em casa. A predisposição para apertar o gatilho é alta.
#
#
# citação http://repositorio.ipea.gov.br/bitstream/11058/2927/1/TD_1721.pdf

# %% [markdown]
# * Tem que entrar aqui também numero de portes de armas
# * Numero de feminicidios
# * Numero de assaltos a mao armada
# * Base de dados da policia federal boa com registro de armas de fogo e ocorrencias
# https://servicos.dpf.gov.br/dadosabertos/SINARM/

# %% [markdown]
# 1ª Base de dados https://www.ipea.gov.br/atlasviolencia/filtros-series (Atlas da Violência)
# Séria que retrata quantidade de homicídios por arma de fogos ano-a-ano no Brasil.
# -> Nome do arquivo 'homicidios-por-armas-de-fogo.csv'
# -> A série tinha dados apenas até 2019 , os dados foram complementados com estas fontes:
# https://www.bbc.com/portuguese/brasil-57844477#:~:text=Aumento%20de%20homic%C3%ADdios,provocados%20por%20armas%20de%20fogo.
# https://g1.globo.com/monitor-da-violencia/noticia/2022/02/21/numero-de-assassinatos-cai-7percent-no-brasil-em-2021-e-e-o-menor-da-serie-historica.ghtml

# %%
# Importando bibliotecas e configurando gráficos
import pandas as pd
import plotly.express as px
# %matplotlib inline

# %%
# Criando DataFrames
df_mortes = pd.read_csv('homicidios-por-armas-de-fogo.csv', sep=';', encoding='utf8', usecols=[2, 3])
display(df_mortes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\manda\OneDrive\Documents\GitHub\Desarmamento-Brasil\Clique aqui para abrir a Análise.ipynb Cell 96' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/manda/OneDrive/Documents/GitHub/Desarmamento-Brasil/Clique%20aqui%20para%20abrir%20a%20An%C3%A1lise.ipynb#ch0000094?line=0'>1</a> # Criando DataFrames
# ----> <a href='vscode-notebook-cell:/c%3A/Users/manda/OneDrive/Documents/GitHub/Desarmamento-Brasil/Clique%20aqui%20para%20abrir%20a%20An%C3%A1lise.ipynb#ch0000094?line=1'>2</a> df_mortes = pd.read_csv('homicidios-por-armas-de-fogo.csv', sep=';', encoding='utf8', usecols=[2, 3])
#       <a href='vscode-notebook-cell:/c%3A/Users/manda/OneDrive/Documents/GitHub/Desarmamento-Brasil/Clique%20aqui%20para%20abrir%20a%20An%C3%A1lise.ipynb#ch0000094?line=2'>3</a> display(df_mortes)
#
# File c:\Users\manda\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File c:\Users\manda\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File c:\Users\manda\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=571'>572</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=573'>574</a> # Create the parser.
# --> <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=574'>575</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=576'>577</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#
# File c:\Users\manda\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=929'>930</a>     self.options["has_index_names"] = kwds["has_index_names"]
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=931'>932</a> self.handles: IOHandles | None = None
# --> <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=932'>933</a> self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\manda\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1212'>1213</a>     mode = "rb"
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1213'>1214</a> # error: No overload variant of "get_handle" matches argument types
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1214'>1215</a> # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1215'>1216</a> # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1216'>1217</a> self.handles = get_handle(  # type: ignore[call-overload]
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1217'>1218</a>     f,
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1218'>1219</a>     mode,
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1219'>1220</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1220'>1221</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1221'>1222</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1222'>1223</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1223'>1224</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1224'>1225</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1225'>1226</a> )
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1226'>1227</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1227'>1228</a> f = self.handles.handle
#
# File c:\Users\manda\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=783'>784</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=784'>785</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=785'>786</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=786'>787</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=787'>788</a>         # Encoding
# --> <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=788'>789</a>         handle = open(
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=789'>790</a>             handle,
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=790'>791</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=791'>792</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=792'>793</a>             errors=errors,
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=793'>794</a>             newline="",
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=794'>795</a>         )
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=795'>796</a>     else:
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=796'>797</a>         # Binary mode
#     <a href='file:///c%3A/Users/manda/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=797'>798</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'homicidios-por-armas-de-fogo.csv'

# %%
# Cálculando a evolução populacional brasileira ano-a-ano
# Fontes IBGE dados populacionais nos anos de  80, 91 , 96 e 2010, quando ocorreram SENSOS
# https://brasilemsintese.ibge.gov.br/populacao/populacao-total-1980-2010.html
# Fonte Banco mundial / United Nations Population Division https://data.worldbank.org/country/brazil
# Fonte Population Pyramid https://www.populationpyramid.net/pt/brasil/2022/
# No final foram descartadas as médias oscilantes e consideradas apenas a da Population Pyramid para maior acuracidade

# Puxando DataFrame que geramos no Excel com as médias das 3 fontes.
df_pop = pd.read_excel('populacaobrasileira.xlsx')

# Setando precisão de cálculo para 2 casa flutuantes
pd.set_option('display.precision', 2)
display(df_pop)

# %%
# Adcionando coluna referente a população em milhões no DataFrame de mortes por arma de fogo 
df_mortes = df_mortes.assign(pop_mi=0)
df_mortes['pop_mi'] = df_pop['Milhoes'].copy()
display(df_mortes)

# o Ano de 2019 estava distoante da série, possivelmente foi fraudado pelo governo, ao buscar outras fontes
# corrigi o valor correto 
# fonte https://www.poder360.com.br/brasil/numero-de-assassinatos-no-brasil-cai-19-em-2019-no-total-sao-41-635-mortes/#:~:text=O%20n%C3%BAmero%20de%20assassinatos%20no,2018%20%E2%80%93quase%2010.000%20a%20menos.
# fonte https://noticias.uol.com.br/confere/ultimas-noticias/2021/10/07/governo-federal-distorce-dados-sobre-violencia-para-defender-acesso-a-armas.htm

# %%
# Cálculando indíce dividindo numero de mortes por arma de fogo pela população no ano
df_mortes = df_mortes.assign(indice=0)
c = 0
for indice in df_mortes['indice']:
    val = ((df_mortes['valor'][c]) / (df_mortes['pop_mi'][c]))
    df_mortes['indice'][c] = val
    c += 1
display(df_mortes)

# %% [markdown]
# # Com base neste indice vamos cálcular o aumento ou diminuição nos homicidíos por arma de fogo em relação a populção geral no ano

# %%
# Arrumando títulos do DataFrame
df_mortes.columns=['Ano', 'Mortes', 'Pop_mi', 'Indice']
df_mortes.head(1)

# %%
import plotly.express as px
gf = px.line(df_mortes, x= 'Ano', y='Indice', title='Indice de mortes por arma de fogo ano-a-ano Brasil 1998 - 2019')
display(gf)
